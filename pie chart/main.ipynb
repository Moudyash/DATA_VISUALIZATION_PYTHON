# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **تجهيز قيم الاشكال**

# %%
    # Data to plot consists of  labels, sizes and colors for each # label
    #النصوص
    labels = 'Python', 'C++', 'Ruby', 'Java'
    #النسبة
    sizes = [215, 130, 245, 210]
    #الالوان
    colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

    explode = (0.1, 0, 0, 0)  # explode 1st slice# لابعاد اول شكل من الدائرة

# %% [markdown]
# # **انشاء الشكل**

# %%
  plt.pie(sizes, explode=explode, labels=labels,
            colors=colors, autopct='%1.1f%%',
            shadow=True, startangle=140,counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5b95b31070>,
#   <matplotlib.patches.Wedge at 0x7f5b95b31760>,
#   <matplotlib.patches.Wedge at 0x7f5b95b43070>,
#   <matplotlib.patches.Wedge at 0x7f5b95b43940>],
#  [Text(-0.03402931297168427, 1.19951740540047, 'Python'),
#   Text(1.0673253138528338, 0.26611402520151023, 'C++'),
#   Text(0.36944878849900864, -1.0361021149851084, 'Ruby'),
#   Text(-1.09120544984655, -0.13881882518300143, 'Java')],
#  [Text(-0.01985043256681582, 0.6997184864836075, '26.9%'),
#   Text(0.5821774439197275, 0.1451531046553692, '16.2%'),
#   Text(0.20151752099945924, -0.5651466081736954, '30.6%'),
#   Text(-0.5952029726435727, -0.07571935919072804, '26.2%')])

# %% [markdown]
# **المحور والعنوان**

# %%
    plt.axis('equal')
    plt.title("pie chart")
# Out:
# Text(0.5, 1.0, 'pie chart')

# %% [markdown]
# **لإضافة قائمة شرح لكل قطعة**

# %%
  plt.legend()#to show small squre contain the data
  plt.legend(title="programing languages:")
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.show()

# %%
    # Data to plot consists of  labels, sizes and colors for each # label
    #النصوص
    labels = 'Python', 'C++', 'Ruby', 'Java'
    #النسبة
    sizes = [215, 130, 245, 210]
    #الالوان
    colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

    explode = (0.1, 0, 0, 0)  # explode 1st slice# لابعاد اول شكل من الدائرة

    # Plot
    ''''
    pie(){
    دالة تستعمل لانشاء المخطط الدائري
    }
    
****** parameters   ************** 
    
    explode{
         Each value represents how far from the center each wedge is displayed
تمثل كل قيمة مدى بعد كل قطعة عن المركز         
    }
     
    
    startangle{
    يتم تعريف متغير startangle بزاوية بالدرجات ، الزاوية الافتراضية هي 0: 
     The startangle parameter is defined with an angle in degrees, default angle is 0:
    }
    shadow{
    Add a shadow to the pie chart
    تستعمل لاظهار ظل خلف المخطط
    }
    Colors{
    You can set the color of each wedge with the colors parameter.
    يمكنك ضبط لون كل قطعة باستخدام معلمة الألوان.
    }
    Legend {
    To add a list of explanation for each wedge
    لإضافة قائمة شرح لكل إسفين
    }
    counterclock{
    لتحديد اتجاه الكسور للمخطط الدائري ،
     يجب عليك تعيين معلمة عداد الساعة إلى صواب أو خطأ (القيمة هي صواب افتراضيا) 
    To specify fractions direction of the pie chart, you must set the counterclock parameter to True or False (value is True by default). 
    }
    
    '''
    plt.pie(sizes, explode=explode, labels=labels,
            colors=colors, autopct='%1.1f%%',
            shadow=True, startangle=140,counterclock=False)

    plt.axis('equal')
    plt.title("pie chart")
    # Adding legend

    plt.legend()#to show small squre contain the data
    plt.legend(title="programing languages:")


    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 48
#      11 # Plot
#      12 ''''
#      13 pie(){
#      14 دالة تستعمل لانشاء المخطط الدائري
#    (...)
#      46
#      47 '''
# ---> 48 plt.pie(sizes, explode=explode, labels=labels,
#      49         colors=colors, autopct='%1.1f%%',
#      50         shadow=True, startangle=140,counterclock=False)
#      52 plt.axis('equal')
#      53 plt.title("pie chart")
#
# NameError: name 'plt' is not defined

# %%
  x = np.random.normal(170, 10, 250)

  plt.style.use('classic')
  plt.hist(x,color ='green',alpha = 0.7)
  plt.title("Histogram")
  plt.xlabel("sepal.width value")
  plt.ylabel("frequency")
  plt.show()
